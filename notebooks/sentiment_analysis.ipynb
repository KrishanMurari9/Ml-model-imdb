# %% [markdown]
# # IMDB Sentiment Analysis
#
# Classical NLP workflow using TF-IDF/CountVectorizer and Logistic Regression, Multinomial Naive Bayes and Linear SVM.

# %%
from datasets import load_dataset
import pandas as pd
dataset = load_dataset('imdb')
train_df = pd.DataFrame(dataset['train'])
test_df = pd.DataFrame(dataset['test'])
train_df.head()

# %%
train_df['label'].value_counts()
train_df['text'].str.split().str.len().describe()

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent / 'src'))
from data_preprocessing import clean_text
clean_text(train_df.loc[0, 'text'])

# %% [markdown]
# ## Training
# The complete reproducible training script is in `src/train.py`. Running it compares six classical configurations and saves the best pipeline.
